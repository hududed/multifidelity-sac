# %%
# %load_ext autoreload
# %autoreload 2
# %aiida
# Out:
# UsageError: Line magic function `%aiida` not found.

# %% [markdown]
# # Create structure using pymatgen

# %%
#!pip install pymatgen

# %%
import sys  
sys.path.insert(0, '../src/')
from view import *
from functions import *

from pymatgen.core.structure import Structure, Lattice

from pymatgen.transformations.advanced_transformations import CubicSupercellTransformation

struct = Structure.from_spacegroup('P6/mmm',
                                  Lattice.hexagonal(2.46,15),
                                  ['C'],
                                  [[1/3,2/3,1/2]])
tfms = CubicSupercellTransformation().apply_transformation(struct)

# %%
len(tfms)
# Out:
# 112

# %%
tfms = tfms*[2,2,1]
view_top(tfms)

# %%
tfms.lattice
# Out:
# Lattice
#     abc : 34.44 34.086759892955506 15.0
#  angles : 90.0 90.0 90.0
#  volume : 17609.220160700814
#       A : 34.44 0.0 2.108841788131742e-15
#       B : 3.552713678800501e-15 34.086759892955506 3.615157351082987e-15
#       C : 0.0 0.0 15.0

# %%
supp = create_large_co('Sc','V',adsorbate=True)
len(supp)
# Out:
# 134

# %%
view_top(supp)

# %% [markdown]
# ## Definitions for creating sac structures

# %% [markdown]
# ### Single TM

# %%
def create_small_(element,adsorbate=True):
    sup = CubicSupercellTransformation().apply_transformation(struct)
    idx = []
    for i,coords in enumerate(sup.cart_coords):
        if coords[0] < 3 : idx.append(i)
        elif coords[0] > 14: idx.append(i)
        elif coords[1] < 3 : idx.append(i) 
        elif coords[1] > 14 : idx.append(i)
    sup.remove_sites(idx)

    sup.remove_sites(find_corner_idx(sup))
    sup.remove_sites(mid_idx(sup))

    for i in around_idx(sup):
        sup[i] = 'N'

    for i in h_idx(sup): sup[i]='H'

    if adsorbate==True:
        sup.append('H',[find_x_center(sup),find_y_center(sup),9.0],coords_are_cartesian=True)
    sup.append(element,[find_x_center(sup),find_y_center(sup),7.5],coords_are_cartesian=True)
    
    return sup


def create_large_(element,adsorbate=True):
    sup = CubicSupercellTransformation().apply_transformation(struct)
    sup = sup*[2,2,1]

    idx = []
    for i,coords in enumerate(sup.cart_coords):
        if coords[0] < 1.5: idx.append(i)
        elif coords[0] > 23: idx.append(i)
        elif coords[1] < 1 : idx.append(i) 
        elif coords[1] > 20 : idx.append(i)
    sup.remove_sites(idx)
    
    sup.remove_sites(find_corner_ix(sup,mid=False))
    
    sup.remove_sites(mid_idx(sup))
    for i in around_idx(sup):
        sup[i] = 'N'

    for i in h_idx(sup): sup[i]='H'
    for i in h_idx2(sup): sup[i]='H'

    if adsorbate==True:
        sup.append('H',[find_x_center(sup),find_y_center(sup),9.0],coords_are_cartesian=True)
    sup.append(element,[find_x_center(sup),find_y_center(sup),7.5],coords_are_cartesian=True)
    return sup

def create_medium_(element,adsorbate=True):
    sup = CubicSupercellTransformation().apply_transformation(struct)
    sup = sup*[2,2,1]

    idx = []
    for i,coords in enumerate(sup.cart_coords):
        if coords[0] < 8 : idx.append(i)
        elif coords[0] > 24.5: idx.append(i)
        elif coords[1] < 9.5 : idx.append(i) 
        elif coords[1] > 24.8 : idx.append(i)
    sup.remove_sites(idx)

    sup.remove_sites(find_corner_ix(sup))

    sup.remove_sites(mid_idx(sup))

    for i in around_idx(sup):
        sup[i] = 'N'

    for i in h_idx(sup): sup[i]='H'

    if adsorbate==True:
        sup.append('H',[find_x_center(sup),find_y_center(sup),9.0],coords_are_cartesian=True)
    sup.append(element,[find_x_center(sup),find_y_center(sup),7.5],coords_are_cartesian=True)
    return sup

# %% [markdown]
# ### Co-TM

# %%
def create_large_co(element1,element2,adsorbate=True):
    
    sup = CubicSupercellTransformation().apply_transformation(struct)
    sup = sup*[2,2,1]

    idx = []
    for i,coords in enumerate(sup.cart_coords):
        if coords[0] < 1.5: idx.append(i)
        elif coords[0] > 23: idx.append(i)
        elif coords[1] < 1 : idx.append(i) 
        elif coords[1] > 20 : idx.append(i)
    sup.remove_sites(idx)

    sup.remove_sites(find_corner_ix(sup,mid=False))

    sup.remove_sites(mid_idx_co(sup))
    for i in around_idx_co(sup):
        sup[i] = 'N'

    for i in h_idx(sup): sup[i]='H'
    for i in h_idx2(sup): sup[i]='H'

    tm1 = [find_x_center_co(sup)[0],
           find_y_center_co(sup),
           7.5]
    tm2 = [find_x_center_co(sup)[1],
           find_y_center_co(sup),
           7.5]
    h1 =  [find_x_center_co(sup)[0],
           find_y_center_co(sup),
           9.0]
    h2 =  [find_x_center_co(sup)[1],
           find_y_center_co(sup),
           9.0]
    
    if adsorbate==True:
        sup.append('H',h1,coords_are_cartesian=True)
        sup.append('H',h2,coords_are_cartesian=True)

    sup.append(element1,tm1,coords_are_cartesian=True) #(11.07,12.07)
    sup.append(element2,tm2,coords_are_cartesian=True) #(13.53,12.07)
    
    return sup

# %% [markdown]
# ## View Structures

# %%
view_top(create_large_('Sc'))

# %%
sup = CubicSupercellTransformation().apply_transformation(struct)
sup = sup*[2,2,1]

idx = []
for i,coords in enumerate(sup.cart_coords):
    if coords[0] < 1.5: idx.append(i)
    elif coords[0] > 23: idx.append(i)
    elif coords[1] < 1 : idx.append(i) 
    elif coords[1] > 20 : idx.append(i)
sup.remove_sites(idx)

sup.remove_sites(find_corner_ix(sup,mid=False))

sup.remove_sites(mid_idx(sup))
for i in around_idx(sup):
    sup[i] = 'N'

for i in h_idx(sup): sup[i]='H'
for i in h_idx2(sup): sup[i]='H'

if adsorbate==True:
    sup.append('H',[find_x_center(sup),find_y_center(sup),9.0],coords_are_cartesian=True)
sup.append(element,[find_x_center(sup),find_y_center(sup),7.5],coords_are_cartesian=True)

# %% [markdown]
# ### View structures

# %%
med = create_large_1('Sc')
view_top(med)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-d5c9bbc48841> in <module>
# ----> 1 med = create_large_1('Sc')
#       2 view_top(med)
#
# NameError: name 'create_large_1' is not defined

# %%
view_t

# %%
med = create_medium_('Sc')
view_top(med)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-56f0c45feb9c> in <module>
# ----> 1 med = create_medium_('Sc')
#       2 view_top(med)
#
# NameError: name 'create_medium_' is not defined

# %%
med = create_small_('Sc')
view_top(med)

# %% [markdown]
# ###  OLD code FOR HEXAGONAL structures

# %%
# ## OLD FOR HEXAGONAL
# def create_small(element,adsorbate=True):
#     sup = (struct*[16,16,1])

#     idx = []
#     for i,coords in enumerate(sup.cart_coords):
#         if coords[0] < -1.3 : idx.append(i)
#         elif coords[0] > 8.7: idx.append(i)
#         elif coords[1] < 3 : idx.append(i) 
#         elif coords[1] > 14.2 : idx.append(i)
#     sup.remove_sites(idx)

#     sup.translate_sites(np.arange(0,len(sup),1),[0.28,0.22,0]) # translate so that no atoms are in negative x
#     sup.remove_sites(find_corner_idx(sup))
#     sup.remove_sites(mid_idx(sup))

#     for i in around_idx(sup):
#         sup[i] = 'N'

#     for i in h_idx(sup): sup[i]='H'

#     if adsorbate==True:
#         sup.append('H',[find_x_center(sup),find_y_center(sup),9.0],coords_are_cartesian=True)
#     sup.append(element,[find_x_center(sup),find_y_center(sup),7.5],coords_are_cartesian=True)
    
#     return sup

# def create_medium(element,adsorbate=True):
#     sup = (struct*[16,16,1])

#     idx = []
#     for i,coords in enumerate(sup.cart_coords):
#         if coords[0] < -1.1 : idx.append(i)
#         elif coords[0] > 15: idx.append(i)
#         elif coords[1] < 3 : idx.append(i) 
#         elif coords[1] > 18 : idx.append(i)
#     sup.remove_sites(idx)

#     sup.remove_sites(find_corner_idx(sup))
# #     sup.remove_sites(find_corner_idx(sup))

# #     sup.remove_sites(mid_idx(sup))

# #     for i in around_idx(sup):
# #         sup[i] = 'N'

# #     for i in h_idx(sup): sup[i]='H'

# #     if adsorbate==True:
# #         sup.append('H',[find_x_center(sup),find_y_center(sup),9.0],coords_are_cartesian=True)
# #     sup.translate_sites(np.arange(0,len(sup),1),[0.2,0.2,0])
# #     sup.append(element,[find_x_center(sup),find_y_center(sup),7.5],coords_are_cartesian=True)
#     return sup

# def create_large(element,adsorbate=True):
#     sup = (struct*[16,16,1])

#     idx = []
#     for i,coords in enumerate(sup.cart_coords):
#         if coords[0] < 1.5: idx.append(i)
#         elif coords[0] > 23: idx.append(i)
#         elif coords[1] < 1 : idx.append(i) 
#         elif coords[1] > 20 : idx.append(i)
#     sup.remove_sites(idx)

#     sup.translate_sites(np.arange(0,len(sup),1),[0.04,0.15,0])

#     sup.remove_sites(find_corner_idx(sup))
#     sup.remove_sites(find_corner_idx(sup))
#     sup.remove_sites(find_corner_idx(sup))
#     sup.remove_sites(find_corner_idx(sup))

#     sup.remove_sites(xcorner_idx(sup))

#     sup.remove_sites(mid_idx(sup))
#     for i in around_idx(sup):
#         sup[i] = 'N'

#     for i in h_idx(sup): sup[i]='H'
#     for i in h_idx2(sup): sup[i]='H'

#     if adsorbate==True:
#         sup.append('H',[find_x_center(sup),find_y_center(sup),9.0],coords_are_cartesian=True)
#     sup.append(element,[find_x_center(sup),find_y_center(sup),7.5],coords_are_cartesian=True)
#     return sup

# %% [markdown]
# ### Create list of structures

# %%
tms = ['Sc','Ti','V','Cr','Mn','Fe','Co','Ni','Cu','Zn','Zr','Nb','Mo','Tc',\
     'Ru','Rh','Pd','Ag','Cd','Hf','Ta','W','Re','Os','Ir','Pt','Au']

small_total=[]
for tm in tms:
    small_total.append(create_small_(tm))
    
medium_total=[]
for tm in tms:
    medium_total.append(create_medium_(tm))

large_total=[]
for tm in tms:
    large_total.append(create_large_(tm))
    
small=[]
for tm in tms:
    small.append(create_small_(tm,adsorbate=False))
    
medium=[]
for tm in tms:
    medium.append(create_medium_(tm,adsorbate=False))

large=[]
for tm in tms:
    large.append(create_large_(tm,adsorbate=False))

# %%
len(small), len(medium), len(large), len(small_total), len(medium_total), len(large_total)
# Out:
# (27, 27, 27, 27, 27, 27)

# %%
view_top(small_total[24])

# %%
view_side(medium[0])

# %% [markdown]
# ### Write POSCAR file

# %%
from pymatgen.io.vasp.inputs import Poscar

test = Poscar(supp)

# %%
test.write_file('POSCAR_co')

# %%
# !ls
# Out:
# functions.py  POSCAR  __pycache__  sac-graphene.ipynb  view.py

# %%
# !vi POSCAR

# %% [markdown]
# ## Run aiida for all LF

# %%
from aiida import orm
from aiida import plugins
from aiida.plugins import DataFactory
from aiida.engine import submit
from aiida.orm.nodes.data.upf import get_pseudos_from_structure

PwBaseWorkChain = plugins.WorkflowFactory('quantumespresso.pw.base')

code = load_code('qe-6.6-pw@arcc-msi')

structures = small

StructureData = DataFactory("structure")
KpointsData = DataFactory('array.kpoints')
kpoints = KpointsData()
kpoints.set_kpoints_mesh([1,1,1])

inputs = {
    'pw': {
        'code': code,
        'parameters': orm.Dict(dict={
            'CONTROL': {
                'calculation':'scf',
            },
            'SYSTEM':{
                'ecutwfc':150.,
                'occupations':'smearing',
                'degauss':0.02
            },
            'ELECTRONS':{
                'conv_thr':1.e-6,
            }
        }),
        'metadata':{
            'label':'LF-smallH',
            'options':{
                'account':'rd-hea',
                'resources':{
                    'num_machines':1,
                    'num_cores_per_mpiproc':32
                },
                'max_wallclock_seconds':1*24*60*60,
                'max_memory_kb':int(128e6)
            }
        }
    },
    'kpoints': kpoints,
}

for structure in structures:
    inputs['pw']['structure'] = StructureData(pymatgen_structure=structure)
    inputs['pw']['pseudos'] = get_pseudos_from_structure(StructureData(pymatgen=structure),'SSSP')
    submit(PwBaseWorkChain, **inputs)

# %% [markdown]
# ## Run aiida for HF calcs

# %%
a = np.array([13,14,15,16,20,21,22,23,24])
small_redo = [small_total[i] for i in a] # accidentally did 6-LARGE

# %%
view_top(small_redo[1])

# %%
len(small_total[613])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-daddc8b20aba> in <module>
# ----> 1 len(small_total[613])
#
# IndexError: list index out of range

# %%
from aiida import orm
from aiida import plugins
from aiida.plugins import DataFactory, WorkflowFactory
from aiida.engine import submit
from aiida.orm.nodes.data.upf import get_pseudos_from_structure

# PwBaseWorkChain = WorkflowFactory('quantumespresso.pw.base')
PwRelaxWorkChain = WorkflowFactory('quantumespresso.pw.relax')

code = load_code('qe-6.6-pw@arcc-msi')

structures = small_redo

StructureData = DataFactory("structure")
KpointsData = DataFactory('array.kpoints')
kpoints = KpointsData()
kpoints.set_kpoints_mesh([3,3,1])

inputs = {
    'base':{
        'pw': {
            'code': code,
            'parameters': orm.Dict(dict={
                'SYSTEM':{
                    'ecutwfc':300.,
                    'occupations':'smearing',
                    'degauss':0.02
                    
                },
                'ELECTRONS':{
                    'conv_thr':1.e-6,
                }
            }),
            'metadata':{
                'label':'HF-medium',
                'options':{
                    'account':'rd-hea',
                    'resources':{
                        'num_machines':4,
                        'num_cores_per_mpiproc':32
                    },
                    'max_wallclock_seconds':2*24*60*60,
                    'max_memory_kb':int(128e6)
                }
            }
        },
        'kpoints': kpoints,        
    },
    'relaxation_scheme':orm.Str('relax')
}

for structure in structures:
    inputs['structure'] = StructureData(pymatgen=structure)
    inputs['base']['pw']['pseudos'] = get_pseudos_from_structure(StructureData(pymatgen=structure),'SSSP')
#     inputs['base_final_scf']['pw']['pseudos'] = get_pseudos_from_structure(StructureData(pymatgen=structure),'SSSP')
    submit(PwRelaxWorkChain, **inputs)

# %% [markdown]
# ## Results

# %% [markdown]
# ### OLD result for hexagonal small with ads

# %%
small_comp = [StructureData(pymatgen_structure=f).get_formula() for f in small]
small_comp
# Out:
# ['C22H15N4Sc',
#  'C22H15N4Ti',
#  'C22H15N4V',
#  'C22H15CrN4',
#  'C22H15MnN4',
#  'C22H15FeN4',
#  'C22H15CoN4',
#  'C22H15N4Ni',
#  'C22H15CuN4',
#  'C22H15N4Zn',
#  'C22H15N4Zr',
#  'C22H15N4Nb',
#  'C22H15MoN4',
#  'C22H15N4Tc',
#  'C22H15N4Ru',
#  'C22H15N4Rh',
#  'C22H15N4Pd',
#  'C22H15AgN4',
#  'C22H15CdN4',
#  'C22H15HfN4',
#  'C22H15N4Ta',
#  'C22H15N4W',
#  'C22H15N4Re',
#  'C22H15N4Os',
#  'C22H15IrN4',
#  'C22H15N4Pt',
#  'C22H15AuN4']

# %%
out = load_node(945)

# %%
fermi_energy = out.dict.fermi_energy

# %%
bnds = load_node(943)

# %%
bnds.show_mpl(y_origin=fermi_energy, plot_zero_axis=True)
# Out:
# /usr/lib/python3.6/_collections_abc.py:841: MatplotlibDeprecationWarning:
#
#
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#
# <string>:432: UserWarning:
#
# Attempting to set identical left == right == 0.0 results in singular transformations; automatically expanding.

# %% [markdown]
# ### result LF smalle E(cat)

# %%
import pandas as pd
from aiida import orm
from aiida import plugins
from aiida.plugins import DataFactory
from aiida.engine import submit
from aiida.orm.nodes.data.upf import get_pseudos_from_structure

StructureData = DataFactory("structure")
KpointsData = DataFactory('array.kpoints')

small_comp = [StructureData(pymatgen_structure=f).get_formula() for f in small]
d1 = pd.DataFrame(small_comp,columns=['comp'])

LF_small_out=[]
lst_out = [1072,1087,1098,1109,1116,1131,1142,1153,1164,1179,1190,\
         1201,1208,1211,1214,1217,1220,1223,1226,1229,1232,1235,\
         1238,1241,1244,1247,1250]

for i in lst_out:
    LF_small_out.append(load_node(i).outputs.output_parameters.\
                        dict.energy)
d1['Ecat_LF']=LF_small_out
d1.head()
# Out:
#          comp      Ecat_LF
# 0  C22H14N4Sc -8073.369087
# 1  C22H14N4Ti -8446.273768
# 2   C22H14N4V -8796.919334
# 3  C22H14CrN4 -9210.307933
# 4  C22H14MnN4 -9696.611420

# %% [markdown]
# ### results LF small E(cat+H)

# %%
LF_small_out=[]
lst_out = [1398,1409,1423,1431,1446,1457,1468,1479,1490,1501,1512,\
         1524,1534,1537,1540,1543,1546,1549,1552,1555,1558,1561,\
         1564,1567,1570,1573,1576]

for i in lst_out:
    LF_small_out.append(load_node(i).outputs.output_parameters.\
                        dict.energy)
d1['EcatH_LF']=LF_small_out
d1.to_csv('LF_small.csv')

# %% [markdown]
# H = E(cat+H)-E(cat)-0.5E(H2)
#
# G = H + ZPE -T*S

# %% [markdown]
# TO DO : get Energy of H2

# %%
d1['E_LF']=d1['EcatH_LF']-d1['Ecat_LF']+16
d1.reset_index().plot(x='index', y='E_LF',kind='bar')
# Out:
# <AxesSubplot:xlabel='index'>

# %%
d1
# Out:
#           comp       Ecat_LF      EcatH_LF      E_LF
# 0   C22H14N4Sc  -8073.369087  -8087.768491  1.600596
# 1   C22H14N4Ti  -8446.273768  -8462.172420  0.101347
# 2    C22H14N4V  -8796.919334  -8813.241611 -0.322277
# 3   C22H14CrN4  -9210.307933  -9226.668689 -0.360757
# 4   C22H14MnN4  -9696.611420  -9712.865020 -0.253599
# 5   C22H14FeN4 -11303.990431 -11320.131030 -0.140599
# 6   C22H14CoN4 -10885.066271 -10900.681453  0.384818
# 7   C22H14N4Ni -11494.623710 -11508.834535  1.789175
# 8   C22H14CuN4 -12316.453059 -12330.113853  2.339206
# 9   C22H14N4Zn -13102.811109 -13116.243628  2.567482
# 10  C22H14N4Zr  -8169.475602  -8184.769059  0.706542
# 11  C22H14N4Nb -11368.285463 -11384.480727 -0.195264
# 12  C22H14MoN4  -8686.101468  -8702.393556 -0.292088
# 13  C22H14N4Tc  -9014.717549  -9031.056499 -0.338950
# 14  C22H14N4Ru  -9386.804098  -9403.043162 -0.239063
# 15  C22H14N4Rh  -9774.006810  -9789.713106  0.293704
# 16  C22H14N4Pd -10267.581721 -10281.454954  2.126767
# 17  C22H14AgN4 -10729.027890 -10741.819377  3.208512
# 18  C22H14CdN4  -8481.800851  -8494.452197  3.348654
# 19  C22H14HfN4  -8355.738463  -8371.518405  0.220059
# 20  C22H14N4Ta  -8750.630500  -8767.068108 -0.437608
# 21   C22H14N4W  -8984.743525  -9001.085952 -0.342427
# 22  C22H14N4Re  -9414.035351  -9430.272073 -0.236722
# 23  C22H14N4Os  -9522.637183  -9538.632069  0.005114
# 24  C22H14IrN4  -9295.243234  -9310.875163  0.368071
# 25  C22H14N4Pt  -9689.182736  -9703.329352  1.853384
# 26  C22H14AuN4 -10557.388528 -10570.169340  3.219188

# %% [markdown]
# ### 150 eV SMALL LF

# %%
lst_out = [15025,15029,15036,15040,15047,15051,15058,15062,15069,\
           15073,15077,15084,15091,15095,15099,15106,15110,15117,\
           15121,15128,15132,15139,15143,15150,15154,15161,15165]

# %%
LF_small_out=[]
lst_out = [15025,15029,15036,15040,15047,15051,15058,15062,15069,\
           15073,15077,15084,15091,15095,15099,15106,15110,15117,\
           15121,15128,15132,15139,15143,15150,15154,15161,15165]
d_1 = pd.DataFrame(small_comp,columns=['comp'])
for i in lst_out:
    LF_small_out.append(load_node(i).outputs.output_parameters.\
                        dict.energy)
d_1['Ecat_LF']=LF_small_out
d_1.head()
# Out:
#          comp      Ecat_LF
# 0  C22H14N4Sc -8073.547780
# 1  C22H14N4Ti -8446.454423
# 2   C22H14N4V -8797.099139
# 3  C22H14CrN4 -9210.491431
# 4  C22H14MnN4 -9696.806126

# %%
d_1
# Out:
#           comp       Ecat_LF      EcatH_LF      E_LF
# 0   C22H14N4Sc  -8073.547780  -8087.945840  1.601941
# 1   C22H14N4Ti  -8446.454423  -8462.355160  0.099263
# 2    C22H14N4V  -8797.099139  -8813.424672 -0.325533
# 3   C22H14CrN4  -9210.491431  -9226.855562 -0.364131
# 4   C22H14MnN4  -9696.806126  -9713.061701 -0.255575
# 5   C22H14FeN4 -11303.489515 -11319.566445 -0.076929
# 6   C22H14CoN4 -10885.272485 -10900.889096  0.383389
# 7   C22H14N4Ni -11494.815352 -11509.025135  1.790217
# 8   C22H14CuN4 -12316.682509 -12330.342126  2.340383
# 9   C22H14N4Zn -13103.029281 -13116.460553  2.568728
# 10  C22H14N4Zr  -8169.649858  -8184.945799  0.704059
# 11  C22H14N4Nb -11368.472227 -11384.674229 -0.202002
# 12  C22H14MoN4  -8686.277981  -8702.575817 -0.297836
# 13  C22H14N4Tc  -9014.897426  -9031.241258 -0.343832
# 14  C22H14N4Ru  -9386.985790  -9403.229318 -0.243529
# 15  C22H14N4Rh  -9774.209208  -9789.919162  0.290045
# 16  C22H14N4Pd -10267.774784 -10281.647200  2.127584
# 17  C22H14AgN4 -10729.207353 -10741.996321  3.211033
# 18  C22H14CdN4  -8482.016885  -8494.666410  3.350475
# 19  C22H14HfN4  -8355.915949  -8371.701295  0.214654
# 20  C22H14N4Ta  -8750.809265  -8767.254188 -0.444922
# 21   C22H14N4W  -8984.930281  -9001.279219 -0.348939
# 22  C22H14N4Re  -9414.251920  -9430.493269 -0.241349
# 23  C22H14N4Os  -9522.830756  -9538.829831  0.000925
# 24  C22H14IrN4  -9295.501858  -9311.136121  0.365737
# 25  C22H14N4Pt  -9689.400363  -9703.546276  1.854087
# 26  C22H14AuN4 -10557.570627 -10570.348522  3.222106

# %%
d_1['E_LF']=d_1['EcatH_LF']-d_1['Ecat_LF']+16
d_1.reset_index().plot(x='index', y='E_LF',kind='bar')
# Out:
# <AxesSubplot:xlabel='index'>

# %% [markdown]
# ### 150 eV SMALL H LF

# %%
tms = ['Sc','Ti','V','Cr','Mn','Fe','Co','Ni','Cu',\
       'Zn','Zr','Nb','Mo','Tc','Ru','Rh','Pd','Ag',\
       'Cd','Hf','Ta','W','Re','Os','Ir','Pt','Au']

# %%
import pandas as pd
from aiida import orm
from aiida import plugins
from aiida.plugins import DataFactory
from aiida.engine import submit
from aiida.orm.nodes.data.upf import get_pseudos_from_structure

StructureData = DataFactory("structure")
KpointsData = DataFactory('array.kpoints')

small_comp = [StructureData(pymatgen_structure=f).get_formula() for f in small]
# d_2 = pd.DataFrame(small_comp,columns=['comp'])

LF_small_out=[]
lst_out = [14699,14703,14710,14714,14721,14725,14732,14736,14743,\
           14747,14754,14758,14765,14769,14776,14780,14787,14791,\
           14798,14802,14809,14813,14820,14824,14831,14835,14839]

for i in lst_out:
    LF_small_out.append(load_node(i).outputs.output_parameters.\
                        dict.energy)
d_1['EcatH_LF']=LF_small_out
d_1.head()
d_1.to_csv('LF_small_150.csv')

# %% [markdown]
# ### 150 eV SMALL HF

# %%
tms = ['Sc','Ti','V','Cr','Mn','Fe','Co','Ni','Cu',\
       'Zn','Zr','Nb','Mo','Tc','Ru','Rh','Pd','Ag',\
       'Cd','Hf','Ta','W','Re','Os','Ir','Pt','Au']

# %%
import pandas as pd
from aiida import orm
from aiida import plugins
from aiida.plugins import DataFactory
from aiida.engine import submit
from aiida.orm.nodes.data.upf import get_pseudos_from_structure

StructureData = DataFactory("structure")
KpointsData = DataFactory('array.kpoints')

small_comp = [StructureData(pymatgen_structure=f).get_formula() for f in small]
d_2 = pd.DataFrame(small_comp,columns=['comp'])

LF_small_out=[]
lst_out = [12388,12396,12407,12418,12429,12440,12451,12462,12470,\
           12481,12492,12503,12511,12807,12815,12826,12837,12848,\
           12859,12867,12878,12889,12900,12908,12919,12930,12941]

for i in lst_out:
    LF_small_out.append(load_node(i).outputs.output_parameters.\
                        dict.energy)
d_2['Ecat_HF']=LF_small_out
d_2.head()
# Out:
#          comp      Ecat_HF
# 0  C22H14N4Sc -8091.524588
# 1  C22H14N4Ti -8463.463853
# 2   C22H14N4V -8813.913891
# 3  C22H14CrN4 -9227.318569
# 4  C22H14MnN4 -9713.702336

# %% [markdown]
# ### 150 eV SMALL+H HF

# %%
tms = ['Sc','Ti','V','Cr','Mn','Fe','Co','Ni','Cu',\
       'Zn','Zr','Nb','Mo','Tc','Ru','Rh','Pd','Ag',\
       'Cd','Hf','Ta','W','Re','Os','Ir','Pt','Au']

# %%
import pandas as pd
from aiida import orm
from aiida import plugins
from aiida.plugins import DataFactory
from aiida.engine import submit
from aiida.orm.nodes.data.upf import get_pseudos_from_structure

StructureData = DataFactory("structure")
KpointsData = DataFactory('array.kpoints')

small_comp = [StructureData(pymatgen_structure=f).get_formula() for f in small]
# d_2 = pd.DataFrame(small_comp,columns=['comp'])

LF_small_out=[]
lst_out = [13285,13293,13304,13315,13326,13678,13905,13356,13367,\
           13378,13916,13697,13924,14395,14403,14414,14425,14046,\
           14057,14068,14436,14447,14458,14466,14477,14128,14139]

for i in lst_out:
    LF_small_out.append(load_node(i).outputs.output_parameters.\
                        dict.energy)
d_2['EcatH_HF']=LF_small_out
d_2.head()
d_2.to_csv('HF_small_300.csv')

# %%
d_2['E_HF']=d_2['EcatH_HF']-d_2['Ecat_HF']+16
d_2.reset_index().plot(x='index', y='E_HF',kind='bar')
# Out:
# <AxesSubplot:xlabel='index'>

# %% [markdown]
# ### results LF medium Ecat

# %%
import pandas as pd

med_comp = [StructureData(pymatgen_structure=f).get_formula() for f in medium]
d2 = pd.DataFrame(med_comp,columns=['comp'])

LF_med_out=[]
lst_out = [1724,1735,1746,1757,1768,1779,1790,1801,1812,1823,1834,
         1845,1856,1863,1866,1869,1872,1875,1878,1881,1884,1887,
         1890,1893,1896,1899,1902]

for i in lst_out:
    LF_med_out.append(load_node(i).outputs.output_parameters.\
                        dict.energy)
d2['Ecat_LF']=LF_med_out
d2.head()
# Out:
#          comp       Ecat_LF
# 0  C56H20N4Sc -16694.239476
# 1  C56H20N4Ti -17067.095006
# 2   C56H20N4V -17417.576682
# 3  C56H20CrN4 -17830.790697
# 4  C56H20MnN4 -18316.972464

# %% [markdown]
# ### results LF medium E(cat+H)

# %%
LF_med_out=[]
lst_out = [2050,2061,2072,2083,2094,2101,2116,2123,2138,2145,2160,\
         2171,2182,2189,2192,2195,2198,2201,2204,2207,2210,2213,\
         2216,2219,2222,2225,2228]

for i in lst_out:
    LF_med_out.append(load_node(i).outputs.output_parameters.\
                        dict.energy)
d2['EcatH_LF']=LF_med_out
d2.head()
d2.to_csv('LF_med.csv')

# %%
d2['E_LF']=d2['EcatH_LF']-d2['Ecat_LF']+16
d2.reset_index().plot(x='index', y='E_LF',kind='bar')
# Out:
# <AxesSubplot:xlabel='index'>

# %% [markdown]
# ### results LF large E(cat) DEL

# %%
import pandas as pd

med_comp = [StructureData(pymatgen_structure=f).get_formula() for f in large]
d3 = pd.DataFrame(med_comp,columns=['comp'])

LF_large_out=[]
lst_out = [2268,2279,2291,2683,2316,2327,2338,2349,2360,2371,2382,\
         2393,2404,2407,2410,2413,2416,2419,2422,2425,2428,2431,\
         2434,2741,2440,2443,2446]

for i in lst_out:
    LF_large_out.append(load_node(i).outputs.output_parameters.\
                        dict.energy)
d3['Ecat_LF']=LF_large_out
d3.head()
# Out:
#           comp       Ecat_LF
# 0  C102H26N4Sc -28325.669648
# 1  C102H26N4Ti -28698.551239
# 2   C102H26N4V -29049.094693
# 3  C102H26CrN4 -29462.366503
# 4  C102H26MnN4 -29948.597083

# %% [markdown]
# ### results LF large E(cat+H) DEL

# %%
LF_large_out=[]
lst_out = [2792,2803,2814,3079,2836,2847,3081,3083,2880,2891,2902,\
         2913,2924,2931,2934,2937,2940,2943,2946,2949,3085,3087,\
         3089,3091,2964,2967,2970]

for i in lst_out:
    LF_large_out.append(load_node(i).outputs.output_parameters.\
                        dict.energy)
d3['EcatH_LF']=LF_large_out
d3.head()
d3.to_csv('LF_large.csv')

# %%
d3['E_LF']=d3['EcatH_LF']-d3['Ecat_LF']+16
d3.reset_index().plot(x='index', y='E_LF',kind='bar')
# Out:
# <AxesSubplot:xlabel='index'>

# %% [markdown]
# ### results HF small E(cat+H)

# %%
import pandas as pd

comp = [StructureData(pymatgen_structure=f).get_formula() for f in small_total]
d4 = pd.DataFrame(comp,columns=['comp'])

HF_large_out=[]
lst_out = [3194,3202,3210,3218,3226,3234,3234,3242,3250,\
          3258,3266,3274,3282,3290,3649,3660,3668,3679,\
          3690,3701,3712,3720,3731,3742,3753,3764,3772]
# lst_out = [3509,3585,3535,3452,3456,3478,3446,3461,3483,3590,3617,\
#          3595,3638,3987,3902,3892,3897,4048,4099,4013,4078,4082,\
#          4116,3948,3977,3931,3982]

for i in lst_out:
    HF_large_out.append(load_node(i).outputs.output_parameters.\
                        dict.energy)
d4['EcatH_HF']=HF_large_out
d4.head()
# Out:
#          comp     EcatH_HF
# 0  C22H15N4Sc -8108.661591
# 1  C22H15N4Ti -8480.227602
# 2   C22H15N4V -8830.430384
# 3  C22H15CrN4 -9243.743458
# 4  C22H15MnN4 -9730.036198

# %% [markdown]
# ### results HF small E(cat)

# %%
HF_large_out=[]
lst_out = [6542,6550,6561,6572,6583,7508,7519,6613,6624,\
          6635,6644,6654,6665,7020,7028,7036,7044,7055,\
           7066,7077,7085,7093,7104,7112,7123,7134,7145]
# lst_out = [6756,6843,6831,6926,6921,7564,7559,6809,6848,6875,6853,\
#          6858,6897,7319,7314,7305,7280,7309,7353,7336,7375,7428,7460,\
#          7438,7358,7443,7433]

for i in lst_out:
    HF_large_out.append(load_node(i).outputs.output_parameters.\
                        dict.energy)
d4['Ecat_HF']=HF_large_out
d4.head()
# d4.to_csv('HF_small.csv')
# Out:
#          comp     EcatH_HF      Ecat_HF
# 0  C22H15N4Sc -8108.661591 -8091.507486
# 1  C22H15N4Ti -8480.227602 -8463.444560
# 2   C22H15N4V -8830.430384 -8813.892950
# 3  C22H15CrN4 -9243.743458 -9227.294617
# 4  C22H15MnN4 -9730.036198 -9713.672137

# %%
d4['E_HF']=d4['EcatH_HF']-d4['Ecat_HF']+16
d4.reset_index().plot(x='index', y='E_HF',kind='bar')
# Out:
# <AxesSubplot:xlabel='index'>

# %% [markdown]
# ### (DEL) HF Medium E(cat)

# %%
import pandas as pd

comp = [StructureData(pymatgen_structure=f).get_formula() for f in medium]
d5 = pd.DataFrame(comp,columns=['comp'])

HF_large_out=[]
lst_out = [7575,7586,7594,7605,7616,7627,7638,7646,7657,\
          7668,7679,7690,7700,8819,8830,8838,8849,8860,\
           8871,8879,8890,8901,8912,8920,8931,8942,8953]
# lst_out = [7923,7927,7935,7971,7975,7844,7919,7854,7979,\
#          7849,7931,7983,7839,9086,9130,9091,9108,9125,9147,9181,\
#          9227,9237,9232,9210,9152,9242,9259]

for i in lst_out:
    HF_large_out.append(load_node(i).outputs.output_parameters.\
                        dict.energy)
d5['Ecat_HF']=HF_large_out
d5.head()
# Out:
#          comp       Ecat_HF
# 0  C56H20N4Sc -16718.166121
# 1  C56H20N4Ti -17090.108203
# 2   C56H20N4V -17440.457502
# 3  C56H20CrN4 -17853.783556
# 4  C56H20MnN4 -18340.106890

# %% [markdown]
# ### (DEL) HF Medium E(cat)+H

# %%
tms = ['Sc','Ti','V','Cr','Mn','Fe','Co','Ni','Cu',\
       'Zn','Zr','Nb','Mo','Tc','Ru','Rh','Pd','Ag',\
       'Cd','Hf','Ta','W','Re','Os','Ir','Pt','Au']

# %%
import pandas as pd

HF_large_out=[]
lst_out = [9468,9479,9487,9498,9509,9520,9528,10557,9550,\
          9561,9569,9580,9591,10568,10638,10649,11160,10668,\
           11171,10690,10701,10709,10720,11179,10742,10750,10758]
# lst_out = [9988,9940,9935,9840,9835,9830,9825,10627,9820,\
#          9945,9983,10022,10005,10973,10929,10877,11231,11214,\
#         11274,11008,11086,11069,11064,11248,10937,10942,10947]

for i in lst_out:
    HF_large_out.append(load_node(i).outputs.output_parameters.\
                        dict.energy)
d5['EcatH_HF']=HF_large_out
d5.head()
# d5.to_csv('HF_med.csv')
# Out:
#          comp       Ecat_HF      EcatH_HF
# 0  C56H20N4Sc -16718.166121 -16735.302199
# 1  C56H20N4Ti -17090.108203 -17107.233363
# 2   C56H20N4V -17440.457502 -17457.198815
# 3  C56H20CrN4 -17853.783556 -17870.298976
# 4  C56H20MnN4 -18340.106890 -18356.526887

# %%
d5['E_HF']=d5['EcatH_HF']-d5['Ecat_HF']+16
d5.reset_index().plot(x='index', y='E_HF',kind='bar')
# Out:
# <AxesSubplot:xlabel='index'>

# %%
d5
# Out:
#           comp       Ecat_HF      EcatH_HF      E_HF
# 0   C56H20N4Sc -16718.166121 -16735.302199 -1.136079
# 1   C56H20N4Ti -17090.108203 -17107.233363 -1.125160
# 2    C56H20N4V -17440.457502 -17457.198815 -0.741313
# 3   C56H20CrN4 -17853.783556 -17870.298976 -0.515420
# 4   C56H20MnN4 -18340.106890 -18356.526887 -0.419997
# 5   C56H20FeN4 -19946.887564 -19963.205427 -0.317862
# 6   C56H20CoN4 -19528.795589 -19544.861144 -0.065556
# 7   C56H20N4Ni -20138.586862 -20153.228824  1.358038
# 8   C56H20CuN4 -20960.495970 -20974.940744  1.555226
# 9   C56H20N4Zn -21747.252596 -21762.306765  0.945831
# 10  C56H20N4Zr -16815.072387 -16833.839902 -2.767515
# 11  C56H20N4Nb -20012.872747 -20030.923853 -2.051106
# 12  C56H20MoN4 -17330.047238 -17347.557127 -1.509889
# 13  C56H20N4Tc -17658.564362 -17675.542804 -0.978442
# 14  C56H20N4Ru -18030.725485 -18047.498999 -0.773515
# 15  C56H20N4Rh -18418.250905 -18434.618376 -0.367471
# 16  C56H20N4Pd -18912.255029 -18926.745530  1.509499
# 17  C56H20AgN4 -19374.183288 -19389.051109  1.132179
# 18  C56H20CdN4 -17128.472572 -17144.932181 -0.459609
# 19  C56H20HfN4 -17001.331600 -17020.177895 -2.846295
# 20  C56H20N4Ta -17395.381389 -17413.554391 -2.173001
# 21   C56H20N4W -17629.004271 -17646.625938 -1.621667
# 22  C56H20N4Re -18058.173438 -18075.317322 -1.143884
# 23  C56H20N4Os -18166.759989 -18183.503936 -0.743947
# 24  C56H20IrN4 -17939.759325 -17956.275393 -0.516068
# 25  C56H20N4Pt -18334.249414 -18349.091448  1.157966
# 26  C56H20AuN4 -19202.806732 -19216.582097  2.224635

# %% [markdown]
# ### HF Large E(cat)

# %%
d5.plot

# %%
d5.drop('diff', axis=1, inplace=True)

# %%
7465-Co

# %% [markdown]
# ## Restarting calculations

# %% [markdown]
# So this restart SCF probably only works with SCF calculations or BaseWorkChain for now.
#
#
# TO-DO:
# How to restart workflow at a specific calculation node that failed?

# %%
def restart_scf(node):
    fail_1 = load_node(node)
    restart_builder = fail_1.get_builder_restart()
    parameters = restart_builder.parameters.get_dict()
    parameters['CONTROL']['restart_mode'] = 'restart'
    restart_builder.parameters = Dict(dict=parameters)
    restart_builder.parent_folder = fail_1.outputs.remote_folder
    restart_builder.metadata.label = 'Restart from PwCalculation<{}>'.format(fail_1.pk)
    return restart_builder

# %%
from aiida.engine import submit

fails = [2825,2858,2869,2952,2955,2958,2961]

for i in fails:
    restart_node = submit(restart_scf(i))

# %% [markdown]
# ### Relax

# %%
2753 2764

# %% [markdown]
# # Query

# %%
PwCalculation = CalculationFactory('quantumespresso.pw')
from datetime import datetime, timedelta

qb = QueryBuilder()
qb.append(PwCalculation,
          filters={
              'and': [
                  {'ctime': {'>': datetime.now() - timedelta(days=1)}},
                  {'label': {'==':'HF-small'}}
              ]}, tag='pw');
qb.append(Dict, tag='results',
        project=['attributes.energy', 'attributes.energy_units'
                ],with_incoming='pw');
qb.append(Node, tag='nodes',
        project=['id'],with_incoming='pw');
qb.all()
# Out:
# [[-9227.2946172784, 'eV', 6926],
#  [-9227.2946172784, 'eV', 6925],
#  [-9227.2946172784, 'eV', 6924],
#  [-9227.2946172784, 'eV', 6923],
#  [-9227.2946172784, 'eV', 6922],
#  [-9227.2946172784, 'eV', 6916],
#  [-9713.6721374783, 'eV', 6921],
#  [-9713.6721374783, 'eV', 6920],
#  [-9713.6721374783, 'eV', 6919],
#  [-9713.6721374783, 'eV', 6918],
#  [-9713.6721374783, 'eV', 6917],
#  [-9713.6721374783, 'eV', 6904],
#  [-9227.2946219043, 'eV', 6909],
#  [-9227.2946219043, 'eV', 6908],
#  [-9227.2946219043, 'eV', 6907],
#  [-9227.2946219043, 'eV', 6906],
#  [-9227.2946219043, 'eV', 6905],
#  [-9227.2946219043, 'eV', 6720],
#  [-8703.723416116, 'eV', 6897],
#  [-8703.723416116, 'eV', 6896],
#  [-8703.723416116, 'eV', 6895],
#  [-8703.723416116, 'eV', 6894],
#  [-8703.723416116, 'eV', 6889],
#  [-8703.723416116, 'eV', 6887],
#  [-9713.6721425124, 'eV', 6893],
#  [-9713.6721425124, 'eV', 6892],
#  [-9713.6721425124, 'eV', 6891],
#  [-9713.6721425124, 'eV', 6890],
#  [-9713.6721425124, 'eV', 6888],
#  [-9713.6721425124, 'eV', 6721],
#  [-13120.684477308, 'eV', 6875],
#  [-13120.684477308, 'eV', 6874],
#  [-13120.684477308, 'eV', 6873],
#  [-13120.684477308, 'eV', 6872],
#  [-13120.684477308, 'eV', 6871],
#  [-13120.684477308, 'eV', 6870],
#  [-8703.723428089, 'eV', 6880],
#  [-8703.723428089, 'eV', 6879],
#  [-8703.723428089, 'eV', 6878],
#  [-8703.723428089, 'eV', 6877],
#  [-8703.723428089, 'eV', 6876],
#  [-8703.723428089, 'eV', 6729],
#  [-13120.684483566, 'eV', 6863],
#  [-13120.684483566, 'eV', 6862],
#  [-13120.684483566, 'eV', 6861],
#  [-13120.684483566, 'eV', 6860],
#  [-13120.684483566, 'eV', 6859],
#  [-13120.684483566, 'eV', 6726],
#  [-11386.296212739, 'eV', 6858],
#  [-11386.296212739, 'eV', 6857],
#  [-11386.296212739, 'eV', 6856],
#  [-11386.296212739, 'eV', 6855],
#  [-11386.296212739, 'eV', 6854],
#  [-11386.296212739, 'eV', 6838],
#  [-12333.856049117, 'eV', 6848],
#  [-12333.856049117, 'eV', 6847],
#  [-12333.856049117, 'eV', 6846],
#  [-12333.856049117, 'eV', 6845],
#  [-12333.856049117, 'eV', 6844],
#  [-12333.856049117, 'eV', 6804],
#  [-8463.4445604764, 'eV', 6843],
#  [-8463.4445604764, 'eV', 6842],
#  [-8463.4445604764, 'eV', 6841],
#  [-8463.4445604764, 'eV', 6840],
#  [-8463.4445604764, 'eV', 6839],
#  [-8463.4445604764, 'eV', 6793],
#  [-8813.8929501209, 'eV', 6831],
#  [-8813.8929501209, 'eV', 6830],
#  [-8813.8929501209, 'eV', 6829],
#  [-8813.8929501209, 'eV', 6828],
#  [-8813.8929501209, 'eV', 6822],
#  [-8813.8929501209, 'eV', 6781],
#  [-11386.296214643, 'eV', 6827],
#  [-11386.296214643, 'eV', 6826],
#  [-11386.296214643, 'eV', 6825],
#  [-11386.296214643, 'eV', 6824],
#  [-11386.296214643, 'eV', 6821],
#  [-11386.296214643, 'eV', 6728],
#  [-8188.5700432266, 'eV', 6853],
#  [-8188.5700432266, 'eV', 6852],
#  [-8188.5700432266, 'eV', 6851],
#  [-8188.5700432266, 'eV', 6850],
#  [-8188.5700432266, 'eV', 6849],
#  [-8188.5700432266, 'eV', 6823],
#  [-8188.5700444511, 'eV', 6814],
#  [-8188.5700444511, 'eV', 6813],
#  [-8188.5700444511, 'eV', 6812],
#  [-8188.5700444511, 'eV', 6811],
#  [-8188.5700444511, 'eV', 6810],
#  [-8188.5700444511, 'eV', 6727],
#  [-11511.897726796, 'eV', 6809],
#  [-11511.897726796, 'eV', 6808],
#  [-11511.897726796, 'eV', 6807],
#  [-11511.897726796, 'eV', 6806],
#  [-11511.897726796, 'eV', 6805],
#  [-11511.897726796, 'eV', 6768],
#  [-12333.856053743, 'eV', 6797],
#  [-12333.856053743, 'eV', 6796],
#  [-12333.856053743, 'eV', 6795],
#  [-12333.856053743, 'eV', 6794],
#  [-12333.856053743, 'eV', 6792],
#  [-12333.856053743, 'eV', 6725],
#  [-8463.4445680956, 'eV', 6785],
#  [-8463.4445680956, 'eV', 6784],
#  [-8463.4445680956, 'eV', 6783],
#  [-8463.4445680956, 'eV', 6782],
#  [-8463.4445680956, 'eV', 6780],
#  [-8463.4445680956, 'eV', 6718],
#  [-8813.8929565156, 'eV', 6773],
#  [-8813.8929565156, 'eV', 6772],
#  [-8813.8929565156, 'eV', 6771],
#  [-8813.8929565156, 'eV', 6770],
#  [-8813.8929565156, 'eV', 6769],
#  [-8813.8929565156, 'eV', 6719],
#  [-11511.897728156, 'eV', 6761],
#  [-11511.897728156, 'eV', 6760],
#  [-11511.897728156, 'eV', 6759],
#  [-11511.897728156, 'eV', 6758],
#  [-11511.897728156, 'eV', 6757],
#  [-11511.897728156, 'eV', 6724],
#  [-8091.5074859495, 'eV', 6756],
#  [-8091.5074859495, 'eV', 6755],
#  [-8091.5074859495, 'eV', 6754],
#  [-8091.5074859495, 'eV', 6753],
#  [-8091.5074859495, 'eV', 6752],
#  [-8091.5074859495, 'eV', 6751],
#  [-8091.5074870379, 'eV', 6744],
#  [-8091.5074870379, 'eV', 6743],
#  [-8091.5074870379, 'eV', 6742],
#  [-8091.5074870379, 'eV', 6741],
#  [-8091.5074870379, 'eV', 6740],
#  [-8091.5074870379, 'eV', 6717],
#  [-10885.249265521, 'eV', 6739],
#  [-10885.249265521, 'eV', 6738],
#  [-10885.249265521, 'eV', 6737],
#  [-10885.249265521, 'eV', 6736],
#  [-10885.249265521, 'eV', 6731],
#  [-10885.249265521, 'eV', 6723],
#  [-11303.477833183, 'eV', 6735],
#  [-11303.477833183, 'eV', 6734],
#  [-11303.477833183, 'eV', 6733],
#  [-11303.477833183, 'eV', 6732],
#  [-11303.477833183, 'eV', 6730],
#  [-11303.477833183, 'eV', 6722],
#  [None, None, 6531],
#  [None, None, 6530],
#  [None, None, 6529],
#  [None, None, 6528],
#  [None, None, 6495],
#  [None, None, 6523],
#  [None, None, 6522],
#  [None, None, 6521],
#  [None, None, 6520],
#  [None, None, 6493],
#  [None, None, 6527],
#  [None, None, 6526],
#  [None, None, 6525],
#  [None, None, 6524],
#  [None, None, 6494],
#  [-9001.8972039741, 'eV', 6515],
#  [-9001.8972039741, 'eV', 6514],
#  [-9001.8972039741, 'eV', 6513],
#  [-9001.8972039741, 'eV', 6512],
#  [-9001.8972039741, 'eV', 6511],
#  [-9001.8972039741, 'eV', 6485],
#  [None, None, 6519],
#  [None, None, 6518],
#  [None, None, 6517],
#  [None, None, 6516],
#  [None, None, 6492],
#  [-8768.0953638672, 'eV', 6510],
#  [-8768.0953638672, 'eV', 6509],
#  [-8768.0953638672, 'eV', 6508],
#  [-8768.0953638672, 'eV', 6507],
#  [-8768.0953638672, 'eV', 6506],
#  [-8768.0953638672, 'eV', 6484]]

# %%
from view import *

st = load_node(10626) # Ni

view_talk(st.get_pymatgen_structure())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-fdb28f29e1fb> in <module>
#       1 from view import *
#       2
# ----> 3 st = load_node(10626) # Ni
#       4
#       5 view_talk(st.get_pymatgen_structure())
#
# NameError: name 'load_node' is not defined

# %%
from view import *

st = load_node(11213) # Ag

view_talk(st.get_pymatgen_structure())

# %%
#Cd

from view import *

st = load_node(11273)

view_talk(st.get_pymatgen_structure())

# %%
from ase_notebook import AseView, ViewConfig, get_example_atoms, concatenate_svgs, get_example_atoms
